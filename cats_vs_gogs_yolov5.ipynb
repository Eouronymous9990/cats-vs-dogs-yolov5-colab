# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -r requirements.txt  # install
# !pip install roboflow

# %%
import torch
import os
from IPython.display import Image,clear_output

# %%
from roboflow import Roboflow
api_key = "aAoD5tXmlanRfKEq3hBL"
rf = Roboflow(api_key=api_key, model_format="yolov5", notebook="ultralytics")

# %%
os.environ["DATASET_DIRECTORY"]="/content/images"

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="aAoD5tXmlanRfKEq3hBL")
project = rf.workspace("cats-vs-dogs-bnrcj").project("cats-u2cjd")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/images/cats-1 in yolov5pytorch:: 100%|██████████| 411/411 [00:00<00:00, 4541.59it/s]

# %%
# !python train.py --img 416 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5n.pt --cache
# Out:
# 2023-10-29 13:27:00.217144: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-29 13:27:00.217209: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-29 13:27:00.217249: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source  /content/Maine_Coon_176_jpg.rf.93c64e88fdabbfdce4bd888d6b7d4d7e.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/Maine_Coon_176_jpg.rf.93c64e88fdabbfdce4bd888d6b7d4d7e.jpg, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-230-g53efd07 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 1761871 parameters, 0 gradients, 4.1 GFLOPs
# image 1/1 /content/Maine_Coon_176_jpg.rf.93c64e88fdabbfdce4bd888d6b7d4d7e.jpg: 416x320 1 cats, 42.8ms
# Speed: 0.3ms pre-process, 42.8ms inference, 1.5ms NMS per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/exp3
